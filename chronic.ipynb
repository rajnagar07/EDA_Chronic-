# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('kidney_disease.csv')
df = pd.DataFrame(df) 
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.shape
# Out:
# (400, 26)

# %%
df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
df.drop('id',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.columns = ['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell',
              'pus_cell_clumps', 'bacteria', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
              'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count', 'red_blood_cell_count',
              'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite', 'peda_edema',
              'aanemia', 'class']

# %%
df.head()
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0             NaN
# 1   7.0            50.0             1.020      4.0    0.0             NaN
# 2  62.0            80.0             1.010      2.0    3.0          normal
# 3  48.0            70.0             1.005      4.0    0.0          normal
# 4  51.0            80.0             1.010      2.0    0.0          normal
#
#    pus_cell pus_cell_clumps    bacteria  blood_glucose_random  ...  \
# 0    normal      notpresent  notpresent                 121.0  ...
# 1    normal      notpresent  notpresent                   NaN  ...
# 2    normal      notpresent  notpresent                 423.0  ...
# 3  abnormal         present  notpresent                 117.0  ...
# 4    normal      notpresent  notpresent                 106.0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# ...

# %%
df.describe()
# Out:
#               age  blood_pressure  specific_gravity     albumin       sugar  \
# count  391.000000      388.000000        353.000000  354.000000  351.000000
# mean    51.483376       76.469072          1.017408    1.016949    0.450142
# std     17.169714       13.683637          0.005717    1.352679    1.099191
# min      2.000000       50.000000          1.005000    0.000000    0.000000
# 25%     42.000000       70.000000          1.010000    0.000000    0.000000
# 50%     55.000000       80.000000          1.020000    0.000000    0.000000
# 75%     64.500000       80.000000          1.020000    2.000000    0.000000
# max     90.000000      180.000000          1.025000    5.000000    5.000000
#
#        blood_glucose_random  blood_urea  serum_creatinine      sodium  \
# count            356.000000  381.000000        383.000000  313.000000
# mean             148.036517   57.425722          3.072454  137.528754
# std               79.281714   50.503006          5.741126   10.408752
# ...

# %%
df.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells             object
# pus_cell                    object
# pus_cell_clumps             object
# bacteria                    object
# blood_glucose_random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# haemoglobin                float64
# packed_cell_volume          object
# white_blood_cell_count      object
# red_blood_cell_count        object
# hypertension                object
# diabetes_mellitus           object
# coronary_artery_disease     object
# appetite                    object
# peda_edema                  object
# aanemia                     object
# class                       object
# dtype: object

# %%
df.packed_cell_volume
# Out:
# 0      44
# 1      38
# 2      31
# 3      32
# 4      35
#        ..
# 395    47
# 396    54
# 397    49
# 398    51
# 399    53
# Name: packed_cell_volume, Length: 400, dtype: object

# %%
df['packed_cell_volume'].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)

# %%
#due to some string columns it is a object column 
# want to convert into a numeric value  

df['packed_cell_volume'] = pd.to_numeric(df['packed_cell_volume'],errors='coerce')  #coerce meaning >> supress the error
#all the string character converted are removed with the help of to_numeric converted into the nan

# %%
df['packed_cell_volume'].dtype
# Out:
# dtype('float64')

# %%
df['packed_cell_volume'].unique()
# Out:
# array([44., 38., 31., 32., 35., 39., 36., 33., 29., 28., nan, 16., 24.,
#        37., 30., 34., 40., 45., 27., 48., 52., 14., 22., 18., 42., 17.,
#        46., 23., 19., 25., 41., 26., 15., 21., 43., 20., 47.,  9., 49.,
#        50., 53., 51., 54.])

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
df['red_blood_cell_count']
# Out:
# 0      5.2
# 1      NaN
# 2      NaN
# 3      3.9
# 4      4.6
#       ...
# 395    4.9
# 396    6.2
# 397    5.4
# 398    5.9
# 399    6.1
# Name: red_blood_cell_count, Length: 400, dtype: object

# %%
df['red_blood_cell_count'].unique()
# Out:
# array(['5.2', nan, '3.9', '4.6', '4.4', '5', '4.0', '3.7', '3.8', '3.4',
#        '2.6', '2.8', '4.3', '3.2', '3.6', '4', '4.1', '4.9', '2.5', '4.2',
#        '4.5', '3.1', '4.7', '3.5', '6.0', '5.0', '2.1', '5.6', '2.3',
#        '2.9', '2.7', '8.0', '3.3', '3.0', '3', '2.4', '4.8', '\t?', '5.4',
#        '6.1', '6.2', '6.3', '5.1', '5.8', '5.5', '5.3', '6.4', '5.7',
#        '5.9', '6.5'], dtype=object)

# %%
df['red_blood_cell_count'] = pd.to_numeric(df['red_blood_cell_count'],errors='coerce')

# %%
df['red_blood_cell_count'].unique()
# Out:
# array([5.2, nan, 3.9, 4.6, 4.4, 5. , 4. , 3.7, 3.8, 3.4, 2.6, 2.8, 4.3,
#        3.2, 3.6, 4.1, 4.9, 2.5, 4.2, 4.5, 3.1, 4.7, 3.5, 6. , 2.1, 5.6,
#        2.3, 2.9, 2.7, 8. , 3.3, 3. , 2.4, 4.8, 5.4, 6.1, 6.2, 6.3, 5.1,
#        5.8, 5.5, 5.3, 6.4, 5.7, 5.9, 6.5])

# %%
df['white_blood_cell_count'] = pd.to_numeric(df['white_blood_cell_count'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      391 non-null    float64
#  1   blood_pressure           388 non-null    float64
#  2   specific_gravity         353 non-null    float64
#  3   albumin                  354 non-null    float64
#  4   sugar                    351 non-null    float64
#  5   red_blood_cells          248 non-null    object
#  6   pus_cell                 335 non-null    object
#  7   pus_cell_clumps          396 non-null    object
#  8   bacteria                 396 non-null    object
#  9   blood_glucose_random     356 non-null    float64
#  10  blood_urea               381 non-null    float64
#  11  serum_creatinine         383 non-null    float64
#  12  sodium                   313 non-null    float64
#  13  potassium                312 non-null    float64
# ...

# %%
categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
numeric_column = [col for col in df.columns if df[col].dtype != 'object']

# %%
for col in categorical_columns:
    print(f"{col} has {df[col].unique()} values \n")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal'] values
#
# pus_cell has ['normal' 'abnormal' nan] values
#
# pus_cell_clumps has ['notpresent' 'present' nan] values
#
# bacteria has ['notpresent' 'present' nan] values
#
# hypertension has ['yes' 'no' nan] values
#
# diabetes_mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# coronary_artery_disease has ['no' 'yes' '\tno' nan] values
#
# appetite has ['good' 'poor' nan] values
#
# peda_edema has ['no' 'yes' nan] values
#
# aanemia has ['no' 'yes' nan] values
#
# class has ['ckd' 'ckd\t' 'notckd'] values

# %%
df['diabetes_mellitus'].replace(to_replace={' yes' : 'yes','\tyes': 'yes','\tno': 'no'},inplace=True)

# %%
df['diabetes_mellitus'].unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df['coronary_artery_disease'].replace(to_replace='\tno',value = 'no',inplace=True)

# %%
df['coronary_artery_disease'].unique()
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
# df['class'].replace(to_replace={'ckd\t':'cdk'},inplace=True)
df['class'] = df['class'].map({'ckd':1,'notckd':0,'ckd\t':1})
#you could have also 1st replace then map with 1 and 0

# %%
df['class'].unique()
# Out:
# array([1, 0])

# %%
#univariate analysis

plt.Figure(figsize=(10,6))
sns.histplot(df['age'].dropna(),kde = True,bins = 20)
plt.title("age distribution")
plt.xlabel('Age')
plt.ylabel("frequency")
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.countplot(data = df ,x = 'hypertension')
# Out:
# <Axes: xlabel='hypertension', ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.boxenplot(data = df, x='class' , y = 'blood_urea',palette='Set3')
plt.xlabel("class")
plt.ylabel("blood urea")
# Out:
# Text(0, 0.5, 'blood urea')

# %%
sns.violinplot(data = df,x = 'class',y = 'serum_creatinine',palette='muted')
# Out:
# <Axes: xlabel='class', ylabel='serum_creatinine'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.countplot(data = df,x ='aanemia',palette='pastel' )
# Out:
# <Axes: xlabel='aanemia', ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
df.appetite.unique()
# Out:
# array(['good', 'poor', nan], dtype=object)

# %%
df.appetite.value_counts()
# Out:
# appetite
# good    317
# poor     82
# Name: count, dtype: int64

# %%
df.appetite.value_counts().plot.pie(autopct = ' %1.1f%% ')
# Out:
# <Axes: ylabel='count'>

# %%
df.appetite.value_counts().plot.pie(autopct = ' %1.1f%% ',color = ['green','pink'],explode = (0,0.1),shadow = True,startangle = 90)
# Out:
# <Axes: ylabel='count'>

# %%
df.pus_cell_clumps
# Out:
# 0      notpresent
# 1      notpresent
# 2      notpresent
# 3         present
# 4      notpresent
#           ...
# 395    notpresent
# 396    notpresent
# 397    notpresent
# 398    notpresent
# 399    notpresent
# Name: pus_cell_clumps, Length: 400, dtype: object

# %%
sns.countplot(data = df,x = 'pus_cell_clumps')
# Out:
# <Axes: xlabel='pus_cell_clumps', ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.histplot(df['white_blood_cell_count'].dropna(),kde = True,bins = 20,color="darkorange",)
# Out:
# <Axes: xlabel='white_blood_cell_count', ylabel='Count'>

# %%
#donut plot >> dount plot dount chart or ring chart >>

# %%
df.diabetes_mellitus.value_counts().plot.pie(autopct = "%1.1f%%",wedgeprops = dict(width = 0.3))
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.countplot(data = df , x ='coronary_artery_disease' )
# Out:
# <Axes: xlabel='coronary_artery_disease', ylabel='count'>

# %%
sns.countplot(data = df,x = 'peda_edema')
# Out:
# <Axes: xlabel='peda_edema', ylabel='count'>

# %%
sns.countplot(data = df,x = df.bacteria)
# Out:
# <Axes: xlabel='bacteria', ylabel='count'>

# %%
#bivariate analysis >> two features at a time

# %%
sns.scatterplot(data = df, y = df.blood_pressure,x = df.age)
# Out:
# <Axes: xlabel='age', ylabel='blood_pressure'>

# %%
sns.scatterplot(data=df, x="age", y="blood_pressure", hue="class", palette="rocket")
# Out:
# <Axes: xlabel='age', ylabel='blood_pressure'>

# %%
sns.boxplot(data = df, x = df.diabetes_mellitus , y  = df.albumin, palette="rocket" )
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='albumin'>

# %%
sns.violinplot(data = df, x = df.diabetes_mellitus , y  = df.albumin, palette="rocket",inner="quartile" )
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='albumin'>

# %%
#stacked bar chart  >> diabetes_mellitus, hyper tension
pd.crosstab(df.diabetes_mellitus,df.hypertension)

#crosss tab summarise the data
# Out:
# hypertension        no  yes
# diabetes_mellitus
# no                 220   41
# yes                 31  106

# %%
diabetic_hypertension = pd.crosstab(df.diabetes_mellitus,df.hypertension)
diabetic_hypertension.plot(kind = 'bar',stacked=True)
# Out:
# <Axes: xlabel='diabetes_mellitus'>

# %%
#multivariate  >> analysis 
cols = [df.age,df.blood_glucose_random,df.serum_creatinine,df.blood_pressure,df['class']]
cols
# Out:
# [0      48.0
#  1       7.0
#  2      62.0
#  3      48.0
#  4      51.0
#         ...
#  395    55.0
#  396    42.0
#  397    12.0
#  398    17.0
#  399    58.0
#  Name: age, Length: 400, dtype: float64,
#  0      121.0
#  1        NaN
#  2      423.0
#  3      117.0
#  4      106.0
#         ...
#  395    140.0
#  396     75.0
#  397    100.0
#  398    114.0
#  399    131.0
#  Name: blood_glucose_random, Length: 400, dtype: float64,
#  0      1.2
#  1      0.8
#  2      1.8
#  3      3.8
#  4      1.4
#        ...
#  395    0.5
#  396    1.2
#  397    0.6
#  398    1.0
#  399    1.1
#  Name: serum_creatinine, Length: 400, dtype: float64,
#  0      80.0
#  1      50.0
#  2      80.0
#  3      70.0
#  4      80.0
#         ...
#  395    80.0
#  396    70.0
#  397    80.0
#  398    60.0
#  399    80.0
#  Name: blood_pressure, Length: 400, dtype: float64,
#  0      1
#  1      1
#  2      1
#  3      1
#  4      1
#        ..
#  395    0
#  396    0
#  397    0
#  398    0
#  399    0
# ...

# %%
cols = ['age','blood_glucose_random','serum_creatinine','blood_pressure','class']  ## customised pairplot
p = sns.PairGrid(df[cols],hue = 'class' ,palette="coolwarm")
p.map_upper(sns.scatterplot) #upper corer plot
p.map_lower(sns.kdeplot,color = 'Blues_d') #diagonal plot
p.map_diag(sns.histplot)#lower corener plot
p.add_legend()
plt.title("pairgrid for selected columns")
plt.show()

# %%
sns.pairplot(df[cols],hue = 'class' ,palette="coolwarm")

# %%
# Assuming you have your DataFrame 'df' loaded
# For example: df = pd.read_csv('your_data.csv')

# 1. Calculate the correlation matrix
corr = df.corr(numeric_only=True)

# 2. Create a mask for the upper triangular portion
mask = np.triu(np.ones_like(corr, dtype=bool))

# 3. Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# 4. Generate the heatmap with improvements
sns.heatmap(corr, 
            mask=mask,           # Apply the mask
            annot=True,          # Show the correlation values
            fmt='.2f',           # Format values to 2 decimal places
            cmap='coolwarm',     # Use a diverging colormap
            linewidths=0.5,      # Add lines between cells
            annot_kws={'size': 8}) # Adjust annotation font size

# 5. Add a title for clarity
plt.title('Correlation Matrix of Features', fontsize=16)

# 6. Display the plot
plt.show()

# %%
plt.Figure(figsize=(15,12))
sns.swarmplot(x = df.diabetes_mellitus,y = df.age,hue = df.hypertension,size = 5)
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='age'>

# %%
fig = px.scatter(df, x = 'age', y = 'blood_pressure', color = 'class', hover_data = ['serum_creatinine', 'haemoglobin'],title = "interactive scatterplot with hover information")
fig.show()

# %%
fig = px.scatter_3d(df, x = 'age', y = 'blood_pressure',z = 'serum_creatinine', color = 'class', title = "3d scatter plot scatterplot")
fig.show()

# %%
import plotly.graph_objects as globl
